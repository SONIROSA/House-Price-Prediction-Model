# %%
#Linear Regression Model for finding out price on basis of BHK

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
a = pd.read_csv('kn.csv')

# %%
print(a)
# Out:
#      Unnamed: 0     price  lotsize  bedroom  bathrms  stories driveway  \
# 0             1   42000.0     5850        3        1        2      yes
# 1             2   38500.0     4000        2        1        1      yes
# 2             3   49500.0     3060        3        1        1      yes
# 3             4   60500.0     6650        3        1        2      yes
# 4             5   61000.0     6360        2        1        1      yes
# ..          ...       ...      ...      ...      ...      ...      ...
# 541         542   91500.0     4800        3        2        4      yes
# 542         543   94000.0     6000        3        2        4      yes
# 543         544  103000.0     6000        3        2        4      yes
# 544         545  105000.0     6000        3        2        2      yes
# 545         546  105000.0     6000        3        1        2      yes
#
#     recroom fullbase gashw airco  garagepl prefarea
# 0        no      yes    no    no         1       no
# ...

# %%
print(a.shape)
# Out:
# (546, 13)

# %%
print(a['bedroom'].describe())
# Out:
# count    546.000000
# mean       2.965201
# std        0.737388
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        6.000000
# Name: bedroom, dtype: float64

# %%
a['bedroom'].isnull().sum()
# Out:
# 0

# %%
x = a['bedroom']
y = a['price']

# %%
print(x)
print(y)
# Out:
# 0      3
# 1      2
# 2      3
# 3      3
# 4      2
#       ..
# 541    3
# 542    3
# 543    3
# 544    3
# 545    3
# Name: bedroom, Length: 546, dtype: int64
# 0       42000.0
# 1       38500.0
# 2       49500.0
# 3       60500.0
# 4       61000.0
#          ...
# 541     91500.0
# 542     94000.0
# 543    103000.0
# 544    105000.0
# 545    105000.0
# Name: price, Length: 546, dtype: float64

# %%
x = np.array(x).reshape(-1,1)

# %%
#print(x)

# %%
o = LinearRegression()

# %%
lm = o.fit(x,y)

# %%
 lm.predict(x)
# Out:
# array([ 68583.37293342,  55313.39284677,  68583.37293342,  68583.37293342,
#         55313.39284677,  68583.37293342,  68583.37293342,  68583.37293342,
#         68583.37293342,  68583.37293342,  68583.37293342,  55313.39284677,
#         68583.37293342,  68583.37293342,  55313.39284677,  55313.39284677,
#         68583.37293342,  81853.35302007,  42043.41276012,  55313.39284677,
#         68583.37293342,  81853.35302007,  68583.37293342,  55313.39284677,
#         55313.39284677,  55313.39284677,  55313.39284677,  55313.39284677,
#         68583.37293342,  68583.37293342,  55313.39284677,  81853.35302007,
#         55313.39284677,  55313.39284677,  55313.39284677,  55313.39284677,
#         55313.39284677,  68583.37293342,  81853.35302007,  55313.39284677,
#         68583.37293342,  68583.37293342,  81853.35302007,  95123.33310672,
#         55313.39284677,  68583.37293342,  55313.39284677,  68583.37293342,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [26], in <module>
# ----> 1 print('Accuracy Score :',accuracy_score(x,z))
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:63, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      61 extra_args = len(args) - len(all_args)
#      62 if extra_args <= 0:
# ---> 63     return f(*args, **kwargs)
#      65 # extra_args > 0
#      66 args_msg = ['{}={}'.format(name, arg)
#      67             for name, arg in zip(kwonly_args[:extra_args],
#      68                                  args[-extra_args:])]
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:202, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     142 """Accuracy classification score.
#     143
# ...

# %%
bedroom = []
for x in range(3):
    a = int(input('Please enter the number of BHKs you are looking for'))
    bedroom.append(a)

bedroom = np.array(bedroom).reshape(-1,1)
z = lm.predict(bedroom)
print(z)
